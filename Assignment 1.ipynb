# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\MONA\Downloads\car_price.csv")

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
data.head(10)
# Out:
#    symboling normalized_losses make fuel_type aspiration num_of_doors  \
# 0          3                 ?  gas       std        two  convertible
# 1          3                 ?  gas       std        two  convertible
# 2          1                 ?  gas       std        two    hatchback
# 3          2               164  gas       std       four        sedan
# 4          2               164  gas       std       four        sedan
# 5          2                 ?  gas       std        two        sedan
# 6          1               158  gas       std       four        sedan
# 7          1                 ?  gas       std       four        wagon
# 8          1               158  gas     turbo       four        sedan
# 9          0                 ?  gas     turbo        two    hatchback
#
#   body_style drive_wheels  engine_location   wheel_base  ...  engine_size  \
# 0        rwd        front             88.6  alfa-romero  ...          130
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num_of_doors       205 non-null    object
#  6   body_style         205 non-null    object
#  7   drive_wheels       205 non-null    object
#  8   engine_location    205 non-null    float64
#  9   wheel_base         205 non-null    object
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %%
import numpy as np
data.replace({'?':np.nan},inplace=True)

# %%
data.head(10)
# Out:
#    symboling normalized_losses make fuel_type aspiration num_of_doors  \
# 0          3               NaN  gas       std        two  convertible
# 1          3               NaN  gas       std        two  convertible
# 2          1               NaN  gas       std        two    hatchback
# 3          2               164  gas       std       four        sedan
# 4          2               164  gas       std       four        sedan
# 5          2               NaN  gas       std        two        sedan
# 6          1               158  gas       std       four        sedan
# 7          1               NaN  gas       std       four        wagon
# 8          1               158  gas     turbo       four        sedan
# 9          0               NaN  gas     turbo        two    hatchback
#
#   body_style drive_wheels  engine_location   wheel_base  ...  engine_size  \
# 0        rwd        front             88.6  alfa-romero  ...          130
# ...

# %%
data.describe(include="all")
# Out:
#          symboling normalized_losses make fuel_type aspiration num_of_doors  \
# count   205.000000               164  205       205        203          205
# unique         NaN                51    2         2          2            5
# top            NaN               161  gas       std       four        sedan
# freq           NaN                11  185       168        114           96
# mean      0.834146               NaN  NaN       NaN        NaN          NaN
# std       1.245307               NaN  NaN       NaN        NaN          NaN
# min      -2.000000               NaN  NaN       NaN        NaN          NaN
# 25%       0.000000               NaN  NaN       NaN        NaN          NaN
# 50%       1.000000               NaN  NaN       NaN        NaN          NaN
# 75%       2.000000               NaN  NaN       NaN        NaN          NaN
# max       3.000000               NaN  NaN       NaN        NaN          NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# make                  0
# fuel_type             0
# aspiration            2
# num_of_doors          0
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %%
data.shape
# Out:
# (205, 26)

# %%
data.dropna(subset=["price"],axis=0,inplace=True)

# %%
data.shape
# Out:
# (201, 26)

# %%
data.describe(include="all")
# Out:
#          symboling normalized_losses make fuel_type aspiration num_of_doors  \
# count   201.000000               164  201       201        199          201
# unique         NaN                51    2         2          2            5
# top            NaN               161  gas       std       four        sedan
# freq           NaN                11  181       165        113           94
# mean      0.840796               NaN  NaN       NaN        NaN          NaN
# std       1.254802               NaN  NaN       NaN        NaN          NaN
# min      -2.000000               NaN  NaN       NaN        NaN          NaN
# 25%       0.000000               NaN  NaN       NaN        NaN          NaN
# 50%       1.000000               NaN  NaN       NaN        NaN          NaN
# 75%       2.000000               NaN  NaN       NaN        NaN          NaN
# max       3.000000               NaN  NaN       NaN        NaN          NaN
#
# ...

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized_losses    37
# make                  0
# fuel_type             0
# aspiration            2
# num_of_doors          0
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 0
# dtype: int64

# %%
data.normalized_losses.value_counts()
# Out:
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 103     5
# 85      5
# 168     5
# 65      5
# 95      5
# 102     5
# 94      5
# 74      5
# 122     4
# 93      4
# 118     4
# 148     4
# 106     4
# 83      3
# 115     3
# 137     3
# 125     3
# 154     3
# 101     3
# 81      2
# 89      2
# 164     2
# 192     2
# 194     2
# 87      2
# 153     2
# 197     2
# 188     2
# 108     2
# 110     2
# 129     2
# 145     2
# 113     2
# 119     2
# 158     2
# 107     1
# 142     1
# 256     1
# 90      1
# 186     1
# 77      1
# 98      1
# 231     1
# 78      1
# 121     1
# Name: normalized_losses, dtype: int64

# %%
data.normalized_losses= data.normalized_losses.astype(float)

# %%
data.normalized_losses=data.normalized_losses.fillna(data.normalized_losses.mean())

# %%
data.normalized_losses.value_counts()
# Out:
# 122.0    41
# 161.0    11
# 91.0      8
# 150.0     7
# 104.0     6
# 134.0     6
# 128.0     6
# 94.0      5
# 74.0      5
# 85.0      5
# 103.0     5
# 168.0     5
# 95.0      5
# 65.0      5
# 102.0     5
# 148.0     4
# 106.0     4
# 93.0      4
# 118.0     4
# 115.0     3
# 154.0     3
# 125.0     3
# 137.0     3
# 101.0     3
# 83.0      3
# 194.0     2
# 110.0     2
# 145.0     2
# 119.0     2
# 197.0     2
# 108.0     2
# 188.0     2
# 129.0     2
# 81.0      2
# 164.0     2
# 192.0     2
# 158.0     2
# 153.0     2
# 87.0      2
# 89.0      2
# 113.0     2
# 121.0     1
# 98.0      1
# 186.0     1
# 78.0      1
# 107.0     1
# 77.0      1
# 90.0      1
# 256.0     1
# 231.0     1
# 142.0     1
# Name: normalized_losses, dtype: int64

# %%
data.aspiration.value_counts()
# Out:
# four    113
# two      86
# Name: aspiration, dtype: int64

# %%
data.aspiration=data.aspiration.fillna("four")

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 4
# stroke               4
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
data.bore.value_counts()
# Out:
# 3.62    23
# 3.19    20
# 3.15    15
# 2.97    12
# 3.03    10
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.39     6
# 3.05     6
# 3.54     6
# 3.58     6
# 3.01     5
# 3.7      5
# 3.35     4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.33     2
# 3.47     2
# 3.5      2
# 3.63     2
# 3.8      2
# 3.24     2
# 3.76     1
# 2.99     1
# 3.6      1
# 3.08     1
# 2.54     1
# 2.68     1
# 2.92     1
# 3.13     1
# 3.61     1
# 3.94     1
# 3.34     1
# Name: bore, dtype: int64

# %%
data.bore=data.bore.astype(float)

# %%
data.bore=data.bore.fillna(data.bore.mean())

# %%
data.stroke=data.stroke.astype(float)
data.stroke=data.stroke.fillna(data.stroke.mean())

# %%
data.horsepower=data.horsepower.astype(float)
data.horsepower=data.horsepower.fillna(data.horsepower.mean())

# %%
data.peak_rpm=data.peak_rpm.astype(float)
data.peak_rpm=data.peak_rpm.fillna(data.peak_rpm.mean())

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
data.shape
# Out:
# (201, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel_type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num_of_doors       201 non-null    object
#  6   body_style         201 non-null    object
#  7   drive_wheels       201 non-null    object
#  8   engine_location    201 non-null    float64
#  9   wheel_base         201 non-null    object
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    object
# ...

# %%
data.describe(include="all")
# Out:
#          symboling  normalized_losses make fuel_type aspiration num_of_doors  \
# count   201.000000          201.00000  201       201        201          201
# unique         NaN                NaN    2         2          2            5
# top            NaN                NaN  gas       std       four        sedan
# freq           NaN                NaN  181       165        115           94
# mean      0.840796          122.00000  NaN       NaN        NaN          NaN
# std       1.254802           31.99625  NaN       NaN        NaN          NaN
# min      -2.000000           65.00000  NaN       NaN        NaN          NaN
# 25%       0.000000          101.00000  NaN       NaN        NaN          NaN
# 50%       1.000000          122.00000  NaN       NaN        NaN          NaN
# 75%       2.000000          137.00000  NaN       NaN        NaN          NaN
# max       3.000000          256.00000  NaN       NaN        NaN          NaN
#
# ...

# %%
data.aspiration.value_counts()
# Out:
# four    115
# two      86
# Name: aspiration, dtype: int64

# %%
data.aspiration=data.aspiration.replace({"four":4,"two":2})

# %%
data.aspiration.value_counts()
# Out:
# 4    115
# 2     86
# Name: aspiration, dtype: int64

# %%
data.num_of_cylinders.value_counts()
# Out:
# four      157
# six        24
# five       10
# eight       4
# two         4
# twelve      1
# three       1
# Name: num_of_cylinders, dtype: int64

# %%
data.num_of_cylinders=data.num_of_cylinders.replace({"four":4,"six":6,"five":5,"eight":8,"two":2,"twelve":12,"three":3})

# %%
data.num_of_cylinders.value_counts()
# Out:
# 4     157
# 6      24
# 5      10
# 8       4
# 2       4
# 12      1
# 3       1
# Name: num_of_cylinders, dtype: int64

# %%
data.rename(columns={"make":"FuelType","fuel_type":"Aspiration","aspiration":"Num_of_doors"},inplace=True)

# %%
data.rename(columns={"num_of_doors":"CarBody","body_style":"drivewheel","drive_wheels":"engine_location","engine_location":"wheel_base","wheel_base":"CarName"},inplace=True)

# %%
data.describe(include="all")
# Out:
#          symboling  normalized_losses FuelType Aspiration  Num_of_doors  \
# count   201.000000          201.00000      201        201    201.000000
# unique         NaN                NaN        2          2           NaN
# top            NaN                NaN      gas        std           NaN
# freq           NaN                NaN      181        165           NaN
# mean      0.840796          122.00000      NaN        NaN      3.144279
# std       1.254802           31.99625      NaN        NaN      0.992008
# min      -2.000000           65.00000      NaN        NaN      2.000000
# 25%       0.000000          101.00000      NaN        NaN      2.000000
# 50%       1.000000          122.00000      NaN        NaN      4.000000
# 75%       2.000000          137.00000      NaN        NaN      4.000000
# max       3.000000          256.00000      NaN        NaN      4.000000
#
#        CarBody drivewheel engine_location  wheel_base CarName  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   FuelType           201 non-null    object
#  3   Aspiration         201 non-null    object
#  4   Num_of_doors       201 non-null    int64
#  5   CarBody            201 non-null    object
#  6   drivewheel         201 non-null    object
#  7   engine_location    201 non-null    object
#  8   wheel_base         201 non-null    float64
#  9   CarName            201 non-null    object
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    int64
# ...

# %%
data.price=data.price.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   FuelType           201 non-null    object
#  3   Aspiration         201 non-null    object
#  4   Num_of_doors       201 non-null    int64
#  5   CarBody            201 non-null    object
#  6   drivewheel         201 non-null    object
#  7   engine_location    201 non-null    object
#  8   wheel_base         201 non-null    float64
#  9   CarName            201 non-null    object
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    object
#  15  num_of_cylinders   201 non-null    int64
# ...

# %%
data.head()
# Out:
#    symboling  normalized_losses FuelType Aspiration  Num_of_doors  \
# 0          3              122.0      gas        std             2
# 1          3              122.0      gas        std             2
# 2          1              122.0      gas        std             2
# 3          2              164.0      gas        std             4
# 4          2              164.0      gas        std             4
#
#        CarBody drivewheel engine_location  wheel_base      CarName  ...  \
# 0  convertible        rwd           front        88.6  alfa-romero  ...
# 1  convertible        rwd           front        88.6  alfa-romero  ...
# 2    hatchback        rwd           front        94.5  alfa-romero  ...
# 3        sedan        fwd           front        99.8         audi  ...
# 4        sedan        4wd           front        99.4         audi  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio  horsepower  \
# ...

# %%
data.corr()
# Out:
#                    symboling  normalized_losses  Num_of_doors  wheel_base  \
# symboling           1.000000           0.466264     -0.672344   -0.535987
# normalized_losses   0.466264           1.000000     -0.361368   -0.056661
# Num_of_doors       -0.672344          -0.361368      1.000000    0.445245
# wheel_base         -0.535987          -0.056661      0.445245    1.000000
# length             -0.365404           0.019424      0.395122    0.876024
# width              -0.242423           0.086802      0.227655    0.814507
# height             -0.550160          -0.373737      0.538383    0.590742
# curb_weight        -0.233118           0.099404      0.208517    0.782097
# num_of_cylinders   -0.118016           0.111362      0.002225    0.348931
# engine_size        -0.110581           0.112360      0.024094    0.572027
# bore               -0.139896          -0.029800      0.119140    0.493203
# stroke             -0.007992           0.055127     -0.007780    0.157964
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data[data.select_dtypes(include=['object']).columns]  = data[  data.select_dtypes(include=['object']   ).columns].apply(le.fit_transform)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized_losses  201 non-null    float64
#  2   FuelType           201 non-null    int32
#  3   Aspiration         201 non-null    int32
#  4   Num_of_doors       201 non-null    int64
#  5   CarBody            201 non-null    int32
#  6   drivewheel         201 non-null    int32
#  7   engine_location    201 non-null    int32
#  8   wheel_base         201 non-null    float64
#  9   CarName            201 non-null    int32
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb_weight        201 non-null    int64
#  14  engine_type        201 non-null    int32
#  15  num_of_cylinders   201 non-null    int64
# ...

# %%
pd.set_option("display.max_columns",26)
data.corr()
# Out:
#                    symboling  normalized_losses  FuelType  Aspiration  \
# symboling           1.000000       4.662638e-01  0.196735   -0.054615
# normalized_losses   0.466264       1.000000e+00  0.101546   -0.006911
# FuelType            0.196735       1.015463e-01  1.000000   -0.408228
# Aspiration         -0.054615      -6.910980e-03 -0.408228    1.000000
# Num_of_doors       -0.672344      -3.613676e-01 -0.186681    0.063017
# CarBody            -0.600333      -2.517751e-01 -0.147654    0.072079
# drivewheel         -0.053056       3.172142e-01 -0.131096    0.094469
# engine_location     0.212339       1.355890e-17  0.040917   -0.057496
# wheel_base         -0.535987      -5.666124e-02 -0.307237    0.256889
# CarName            -0.129645      -2.543563e-01 -0.109330    0.071254
# length             -0.365404       1.942356e-02 -0.211187    0.230085
# width              -0.242423       8.680206e-02 -0.244356    0.305732
# ...

# %%
from sklearn.model_selection import train_test_split
data_x = data.iloc[:,0:25]
data_y = data.iloc[:,-1]

# %%
data_x
# Out:
#      symboling  normalized_losses  FuelType  Aspiration  Num_of_doors  \
# 0            3              122.0         1           0             2
# 1            3              122.0         1           0             2
# 2            1              122.0         1           0             2
# 3            2              164.0         1           0             4
# 4            2              164.0         1           0             4
# ..         ...                ...       ...         ...           ...
# 200         -1               95.0         1           0             4
# 201         -1               95.0         1           1             4
# 202         -1               95.0         1           0             4
# 203         -1               95.0         0           1             4
# 204         -1               95.0         1           1             4
#
#      CarBody  drivewheel  engine_location  wheel_base  CarName  ...  \
# ...

# %%
data_y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 201, dtype: float64

# %%
data_x_train,data_x_test,data_y_train,data_y_test = train_test_split(data_x,data_y,test_size=0.3,random_state=101)

# %%
print(data_x_train.shape)
print(data_y_train.shape)
print("---")
print(data_x_test.shape)
print(data_y_test.shape)
# Out:
# (140, 25)
# (140,)
# ---
# (61, 25)
# (61,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()

# %%
reg.fit(data_x_train,data_y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.intercept_
# Out:
# -67031.3293836598

# %%
reg.coef_
# Out:
# array([ 1.19329798e+02, -7.38203656e+00,  8.68309855e+03,  1.76450971e+03,
#         5.90021408e+02, -1.32331102e+03,  1.64611102e+03,  1.13840890e+04,
#         1.38698200e+02, -1.62789636e+02, -6.03048797e+01,  6.88713966e+02,
#         2.64890380e+02,  2.06211887e+00,  5.72518121e+01, -5.83032357e+02,
#         1.22919555e+02,  1.57902041e+02, -3.14356073e+03, -2.85085246e+03,
#         6.81987252e+02, -4.41333412e+00,  1.15627437e+00, -1.17928317e+02,
#         8.25629568e+01])

# %%
RSq=reg.score(data_x_train,data_y_train)
RSq
# Out:
# 0.9119658179679274

# %%
K=25
N=140
Adj_RSq = 1-(1-RSq)*(N-1)/(N-K-1)
Adj_RSq
# Out:
# 0.8926600762942273

# %%
pred_train = reg.predict(data_x_train)

# %%
error_train = data_y_train - pred_train

# %%
np.mean(error_train)
# Out:
# -3.118267548935754e-13

# %%
reg.fit(data_x_test,data_y_test)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coef=[reg.coef_]
print(reg.intercept_)
print(coef)
# Out:
# -15880.78234194329
# [array([ 1.98644128e+02, -1.80085711e+01, -1.38902189e+03,  1.70681443e+03,
#        -3.39251277e+02,  1.07835221e+03, -1.31339886e+02,  1.23899000e+04,
#         2.43430032e+02, -2.56437215e+02,  1.18607969e+02,  2.67468937e+02,
#         3.24334572e+01, -3.66231418e+00,  1.24567628e+03, -4.32977790e+03,
#         3.29115932e+02,  1.31730470e+02, -1.00533309e+04, -8.50420617e+03,
#         1.62413490e+02, -1.77051665e+00,  2.48709277e+00, -4.11842385e+02,
#         3.52780377e+02])]

# %%
RSq_test = reg.score(data_x_test,data_y_test)

# %%
RSq_test
# Out:
# 0.9255530313211654

# %%
N=61
K=25
Adj_RSq_test = 1-(1-RSq_test)*(N-1)/(N-K-1)
Adj_RSq_test
# Out:
# 0.8723766251219978

# %%
pred_test = reg.predict(data_x_test)

# %%
error_test = data_y_test - pred_test

# %%
np.mean(error_test)
# Out:
# -6.679567645807735e-12

# %%
MSE = np.mean(error_test*error_test)
MAE= np.mean(np.absolute(error_test))
RMSE= np.power(MSE,0.5)
MAPE= np.mean(np.absolute(error_test/data_y_test))*100
Accrcy= 100-MAPE
print("MSE is:{}\nMAE is:{}\nRMSE is:{}\nMAPE is:{} \nAND\nAccuracy is:{} ".format(MSE,MAE,RMSE,MAPE,Accrcy))
# Out:
# MSE is:4615609.989152906
# MAE is:1622.5075679949407
# RMSE is:2148.3970743679824
# MAPE is:15.221712679816916
# AND
# Accuracy is:84.77828732018308

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(error_test)

# %%
sns.distplot(error_test)

# %%
data.to_csv(r"Assignment1_csv_file.csv")

# %%
coeff=pd.DataFrame(index=[data_x_test.columns],columns=["reg.coef_"],data=reg.coef_)

# %%
coeff
# Out:
#                       reg.coef_
# symboling            198.644128
# normalized_losses    -18.008571
# FuelType           -1389.021886
# Aspiration          1706.814425
# Num_of_doors        -339.251277
# CarBody             1078.352214
# drivewheel          -131.339886
# engine_location    12389.900034
# wheel_base           243.430032
# CarName             -256.437215
# length               118.607969
# width                267.468937
# height                32.433457
# curb_weight           -3.662314
# engine_type         1245.676284
# num_of_cylinders   -4329.777897
# engine_size          329.115932
# fuel_system          131.730470
# bore              -10053.330883
# stroke             -8504.206173
# compression_ratio    162.413490
# horsepower            -1.770517
# peak_rpm               2.487093
# city_mpg            -411.842385
# highway_mpg          352.780377
